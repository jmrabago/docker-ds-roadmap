# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn

# %%
print(f"pandas: {pd.__version__}")
print(f"numpy: {np.__version__}")
print(f"sklearn: {sklearn.__version__}")
print("✅ Todo listo")
# Out:
# pandas: 2.1.1
# numpy: 1.24.4
# sklearn: 1.3.1
# ✅ Todo listo

# %%
import pandas as pd
import numpy as np

# Crear dataset de ventas ficticias
df = pd.DataFrame({
    'mes': ['Ene', 'Feb', 'Mar', 'Abr', 'May', 'Jun'],
    'ventas': np.random.randint(1000, 5000, 6),
    'clientes': np.random.randint(50, 200, 6)
})

df.to_csv('ventas.csv', index=False)
print(df)
print("✅ CSV guardado")
# Out:
#    mes  ventas  clientes
# 0  Ene    4478       110
# 1  Feb    4448       198
# 2  Mar    3387       158
# 3  Abr    2609       148
# 4  May    2769       124
# 5  Jun    1094       177
# ✅ CSV guardado

# %%
import os
print(os.getcwd())
# Out:
# /home/jovyan

# %%
import os
os.chdir('/home/jovyan/work')
print(os.getcwd())
# Out:
# /home/jovyan/work
